# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv("results.csv")

# %%
df
# Out:
#                       Model  Accuracy  Precision    Recall  F1 Score  Case
# 0       Logistic Regression  0.800000   0.675000  0.627907  0.650602     1
# 1               Naïve Bayes  0.772414   0.608696  0.651163  0.629213     1
# 2    Support Vector Machine  0.786207   0.666667  0.558140  0.607595     1
# 3       K-Nearest Neighbors  0.737931   0.555556  0.581395  0.568182     1
# 4             Decision Tree  0.779310   0.617021  0.674419  0.644444     1
# 5             Random Forest  0.806897   0.659574  0.720930  0.688889     1
# 6   Bagging (Decision Tree)  0.820690   0.688889  0.720930  0.704545     1
# 7                   XGBoost  0.813793   0.673913  0.720930  0.696629     1
# 8                  LightGBM  0.806897   0.653061  0.744186  0.695652     1
# 9     Multilayer Perceptron  0.710345   0.510638  0.558140  0.533333     1
# 10      Logistic Regression  0.813084   0.724138  0.636364  0.677419     2
# 11              Naïve Bayes  0.775701   0.615385  0.727273  0.666667     2
# 12   Support Vector Machine  0.738318   0.575758  0.575758  0.575758     2
# 13      K-Nearest Neighbors  0.757009   0.629630  0.515152  0.566667     2
# 14            Decision Tree  0.682243   0.488372  0.636364  0.552632     2
# 15            Random Forest  0.785047   0.656250  0.636364  0.646154     2
# 16  Bagging (Decision Tree)  0.766355   0.633333  0.575758  0.603175     2
# 17                  XGBoost  0.794393   0.666667  0.666667  0.666667     2
# 18                 LightGBM  0.803738   0.687500  0.666667  0.676923     2
# 19    Multilayer Perceptron  0.710280   0.527778  0.575758  0.550725     2
# 20      Logistic Regression  0.800000   0.675000  0.627907  0.650602     3
# 21              Naïve Bayes  0.765517   0.595745  0.651163  0.622222     3
# 22   Support Vector Machine  0.765517   0.621622  0.534884  0.575000     3
# 23      K-Nearest Neighbors  0.737931   0.551020  0.627907  0.586957     3
# 24            Decision Tree  0.731034   0.545455  0.558140  0.551724     3
# 25            Random Forest  0.800000   0.666667  0.651163  0.658824     3
# 26  Bagging (Decision Tree)  0.793103   0.644444  0.674419  0.659091     3
# 27                  XGBoost  0.806897   0.666667  0.697674  0.681818     3
# 28                 LightGBM  0.806897   0.659574  0.720930  0.688889     3
# 29    Multilayer Perceptron  0.717241   0.522727  0.534884  0.528736     3
# 30      Logistic Regression  0.751724   0.666667  0.500000  0.571429     4
# 31              Naïve Bayes  0.751724   0.630435  0.604167  0.617021     4
# 32   Support Vector Machine  0.779310   0.710526  0.562500  0.627907     4
# 33      K-Nearest Neighbors  0.765517   0.666667  0.583333  0.622222     4
# 34            Decision Tree  0.737931   0.613636  0.562500  0.586957     4
# 35            Random Forest  0.786207   0.707317  0.604167  0.651685     4
# 36  Bagging (Decision Tree)  0.786207   0.697674  0.625000  0.659341     4
# 37                  XGBoost  0.793103   0.714286  0.625000  0.666667     4
# 38                 LightGBM  0.786207   0.707317  0.604167  0.651685     4
# 39    Multilayer Perceptron  0.744828   0.603774  0.666667  0.633663     4

# %%
metrics = ["Accuracy", "Precision", "Recall", "F1 Score"]

for metric in metrics:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x="Case", y=metric, data=df)
    plt.title(f"{metric} Distribution by Case")
    plt.tight_layout()
    plt.show()
